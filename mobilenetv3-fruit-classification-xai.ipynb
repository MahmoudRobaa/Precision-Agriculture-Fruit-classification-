# %%
import cv2
import numpy as np
import os
import random
from scipy.signal import wiener
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
train_folder = '/kaggle/input/fruits36081class/fruits-360/Training'
total_classes = 0
total_images = 0  # Initialize a variable to store total images

for class_folder in os.listdir(train_folder):
  class_folder_path = os.path.join(train_folder, class_folder)
  if os.path.isdir(class_folder_path):
    total_classes += 1
    images = os.listdir(class_folder_path)
    num_images = len(images)
    print(f"Class: {class_folder}, Number of Images: {num_images}")
    total_images += num_images  # Add current class image count to total

print(f"Total number of classes: {total_classes}")
print(f"Total number of images: {total_images}")
# Out:
# Class: Quince, Number of Images: 490
# Class: Grapefruit White, Number of Images: 492
# Class: Granadilla, Number of Images: 490
# Class: Orange, Number of Images: 479
# Class: Apple Red 3, Number of Images: 429
# Class: Grape White 2, Number of Images: 490
# Class: Tamarillo, Number of Images: 490
# Class: Banana Red, Number of Images: 490
# Class: Pear Monster, Number of Images: 490
# Class: Lemon Meyer, Number of Images: 490
# Class: Passion Fruit, Number of Images: 490
# Class: Cactus fruit, Number of Images: 490
# Class: Pomegranate, Number of Images: 492
# Class: Plum, Number of Images: 447
# Class: Pineapple, Number of Images: 490
# Class: Tomato 1, Number of Images: 738
# Class: Cherry 2, Number of Images: 738
# Class: Apple Red 2, Number of Images: 492
# Class: Avocado ripe, Number of Images: 491
# Class: Dates, Number of Images: 490
# Class: Maracuja, Number of Images: 490
# Class: Papaya, Number of Images: 492
# Class: Cherry Wax Yellow, Number of Images: 492
# Class: Apple Golden 2, Number of Images: 492
# Class: Guava, Number of Images: 490
# Class: Tomato Maroon, Number of Images: 367
# Class: Apple Red Delicious, Number of Images: 490
# Class: Cherry Wax Red, Number of Images: 492
# Class: Kiwi, Number of Images: 466
# Class: Cherry Wax Black, Number of Images: 492
# Class: Limes, Number of Images: 490
# Class: Cantaloupe 2, Number of Images: 492
# Class: Apple Braeburn, Number of Images: 492
# Class: Pear, Number of Images: 492
# Class: Carambula, Number of Images: 490
# Class: Tomato 3, Number of Images: 738
# Class: Cherry 1, Number of Images: 492
# Class: Strawberry, Number of Images: 492
# Class: Lychee, Number of Images: 490
# Class: Rambutan, Number of Images: 492
# Class: Tomato 4, Number of Images: 479
# Class: Grape White, Number of Images: 490
# Class: Pineapple Mini, Number of Images: 493
# Class: Mulberry, Number of Images: 492
# Class: Pear Abate, Number of Images: 490
# Class: Melon Piel de Sapo, Number of Images: 738
# Class: Nectarine, Number of Images: 492
# Class: Salak, Number of Images: 490
# Class: Cocos, Number of Images: 490
# Class: Apple Granny Smith, Number of Images: 492
# Class: Apricot, Number of Images: 492
# Class: Walnut, Number of Images: 735
# Class: Grapefruit Pink, Number of Images: 490
# Class: Tangelo, Number of Images: 490
# Class: Peach Flat, Number of Images: 492
# Class: Tomato Cherry Red, Number of Images: 492
# Class: Pear Williams, Number of Images: 490
# Class: Clementine, Number of Images: 490
# Class: Apple Golden 3, Number of Images: 481
# Class: Apple Red 1, Number of Images: 492
# Class: Cantaloupe 1, Number of Images: 492
# Class: Lemon, Number of Images: 492
# Class: Physalis with Husk, Number of Images: 492
# Class: Pepino, Number of Images: 490
# Class: Huckleberry, Number of Images: 490
# Class: Pitahaya Red, Number of Images: 490
# Class: Apple Golden 1, Number of Images: 492
# Class: Cherry Rainier, Number of Images: 738
# Class: Avocado, Number of Images: 427
# Class: Raspberry, Number of Images: 490
# Class: Strawberry Wedge, Number of Images: 738
# Class: Kaki, Number of Images: 490
# Class: Mandarine, Number of Images: 490
# Class: Kumquats, Number of Images: 490
# Class: Apple Red Yellow, Number of Images: 492
# Class: Physalis, Number of Images: 492
# Class: Peach, Number of Images: 492
# Class: Grape Pink, Number of Images: 492
# Class: Banana, Number of Images: 490
# Class: Mango, Number of Images: 490
# Class: Tomato 2, Number of Images: 672
# Total number of classes: 81
# Total number of images: 41322

# %%
test_folder = '/kaggle/input/fruits36081class/fruits-360/Test'
total_classes = 0
total_images = 0  # Initialize a variable to store total images

for class_folder in os.listdir(test_folder):
  class_folder_path = os.path.join(test_folder, class_folder)
  if os.path.isdir(class_folder_path):
    total_classes += 1
    images = os.listdir(class_folder_path)
    num_images = len(images)
    print(f"Class: {class_folder}, Number of Images: {num_images}")
    total_images += num_images  # Add current class image count to total

print(f"Total number of classes: {total_classes}")
print(f"Total number of images: {total_images}")
# Out:
# Class: Quince, Number of Images: 166
# Class: Grapefruit White, Number of Images: 164
# Class: Granadilla, Number of Images: 166
# Class: Orange, Number of Images: 160
# Class: Apple Red 3, Number of Images: 144
# Class: Grape White 2, Number of Images: 166
# Class: Tamarillo, Number of Images: 166
# Class: Banana Red, Number of Images: 166
# Class: Pear Monster, Number of Images: 166
# Class: Lemon Meyer, Number of Images: 166
# Class: Passion Fruit, Number of Images: 166
# Class: Cactus fruit, Number of Images: 166
# Class: Pomegranate, Number of Images: 164
# Class: Plum, Number of Images: 151
# Class: Pineapple, Number of Images: 166
# Class: Tomato 1, Number of Images: 246
# Class: Cherry 2, Number of Images: 246
# Class: Apple Red 2, Number of Images: 164
# Class: Avocado ripe, Number of Images: 166
# Class: Dates, Number of Images: 166
# Class: Maracuja, Number of Images: 166
# Class: Papaya, Number of Images: 164
# Class: Cherry Wax Yellow, Number of Images: 164
# Class: Apple Golden 2, Number of Images: 164
# Class: Guava, Number of Images: 166
# Class: Tomato Maroon, Number of Images: 127
# Class: Apple Red Delicious, Number of Images: 166
# Class: Cherry Wax Red, Number of Images: 164
# Class: Kiwi, Number of Images: 156
# Class: Cherry Wax Black, Number of Images: 164
# Class: Limes, Number of Images: 166
# Class: Cantaloupe 2, Number of Images: 164
# Class: Apple Braeburn, Number of Images: 164
# Class: Pear, Number of Images: 164
# Class: Carambula, Number of Images: 166
# Class: Tomato 3, Number of Images: 246
# Class: Cherry 1, Number of Images: 164
# Class: Strawberry, Number of Images: 164
# Class: Lychee, Number of Images: 166
# Class: Rambutan, Number of Images: 164
# Class: Tomato 4, Number of Images: 160
# Class: Grape White, Number of Images: 166
# Class: Pineapple Mini, Number of Images: 163
# Class: Mulberry, Number of Images: 164
# Class: Pear Abate, Number of Images: 166
# Class: Melon Piel de Sapo, Number of Images: 246
# Class: Nectarine, Number of Images: 164
# Class: Salak, Number of Images: 162
# Class: Cocos, Number of Images: 166
# Class: Apple Granny Smith, Number of Images: 164
# Class: Apricot, Number of Images: 164
# Class: Walnut, Number of Images: 249
# Class: Grapefruit Pink, Number of Images: 166
# Class: Tangelo, Number of Images: 166
# Class: Peach Flat, Number of Images: 164
# Class: Tomato Cherry Red, Number of Images: 164
# Class: Pear Williams, Number of Images: 166
# Class: Clementine, Number of Images: 166
# Class: Apple Golden 3, Number of Images: 161
# Class: Apple Red 1, Number of Images: 164
# Class: Cantaloupe 1, Number of Images: 164
# Class: Lemon, Number of Images: 164
# Class: Physalis with Husk, Number of Images: 164
# Class: Pepino, Number of Images: 166
# Class: Huckleberry, Number of Images: 166
# Class: Pitahaya Red, Number of Images: 166
# Class: Apple Golden 1, Number of Images: 164
# Class: Cherry Rainier, Number of Images: 246
# Class: Avocado, Number of Images: 143
# Class: Raspberry, Number of Images: 166
# Class: Strawberry Wedge, Number of Images: 246
# Class: Kaki, Number of Images: 166
# Class: Mandarine, Number of Images: 166
# Class: Kumquats, Number of Images: 166
# Class: Apple Red Yellow, Number of Images: 164
# Class: Physalis, Number of Images: 164
# Class: Peach, Number of Images: 164
# Class: Grape Pink, Number of Images: 164
# Class: Banana, Number of Images: 166
# Class: Mango, Number of Images: 166
# Class: Tomato 2, Number of Images: 225
# Total number of classes: 81
# Total number of images: 13877

# %% [markdown]
# # **Importing Libraries**

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset, random_split
from transformers import AutoTokenizer , SwinForImageClassification,ViTForImageClassification
from torchvision import models,transforms, datasets
import torch.optim as optim
import cv2
import os
import numpy as np
from sklearn.preprocessing import LabelEncoder
from PIL import Image
from torch.optim import lr_scheduler
from torch.optim import AdamW

# %%
train_dir = train_folder
test_dir = test_folder
num_classes = total_classes
image_shape = (100, 100)
batch_size = 32

# %% [markdown]
# # **Making Dataset**

# %%
from torch.utils.data import Dataset
from PIL import Image
import os

class MakeDataset(Dataset):
    def __init__(self, root_folder, transform=None):
        self.root_folder = root_folder
        self.transform = transform
        self.classes = sorted(os.listdir(root_folder), key=self.natural_key)
        self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}
        self.images = self.make_dataset()

    def natural_key(self, string_):
        try:
            return int(string_)
        except ValueError:
            return string_

    def make_dataset(self):
        images = []
        for label in self.classes:
            label_folder = os.path.join(self.root_folder, label)
            for image_name in os.listdir(label_folder):
                image_path = os.path.join(label_folder, image_name)
                item = (image_path, self.class_to_idx[label])
                images.append(item)
        return images

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        image_path, label = self.images[index]
        try:
            image = Image.open(image_path).convert("RGB")
        except (OSError, IOError) as e:
            print(f"Skipping corrupted image: {image_path}, Error: {e}")
            # Return a zero tensor and a dummy label in case of error
            image = Image.new('RGB', (100, 100))  # Assuming the image size to be 224x224
            label = -1  # You might want to handle this label properly later

        if self.transform:
            image = self.transform(image)

        return image, label

# %% [markdown]
# # **Transformation on the Data**

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to the required input size
    transforms.RandomHorizontalFlip(p=0.5),  # Randomly flip images horizontally
    transforms.RandomRotation(degrees=20),   # Rotate the image by up to 20 degrees
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # Randomly crop and resize
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),  # Apply small translations
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
])

# %%
train_dataset = MakeDataset(train_dir, transform=transform)
test_dataset=MakeDataset(test_dir, transform=transform)

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # **Data Samples**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define a function to visualize images from a DataLoader
def visualize(loader, num_samples=5):
    # Iterate through the DataLoader to get a batch of data
    for batch_idx, (images, labels) in enumerate(loader):
        # Plot the images
        fig, axes = plt.subplots(1, num_samples, figsize=(15, 3))
        for i in range(num_samples):
            ax = axes[i]
            ax.imshow(np.transpose(images[i], (1, 2, 0)))
            ax.set_title(f"Label: {labels[i]}")
            ax.axis('off')
        plt.show()
        break  # Stop after displaying the first batch

# Visualize samples from the training loader
print("Training Samples:")
visualize(train_loader)


print("Testing Samples:")
visualize(test_loader)
# Out:
# Training Samples:
# Testing Samples:

# %% [markdown]
# # **MobileNetV3_Large**

# %%
model = models.mobilenet_v3_large(pretrained=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Large_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
# 100%|██████████| 21.1M/21.1M [00:00<00:00, 121MB/s]

# %%
in_features = model.classifier[0].in_features

# Modify the classifier layer to match the number of output classes
model.classifier = nn.Sequential(
    nn.Linear(in_features, num_classes),
    nn.Softmax(dim=1)
)

# %%
best_model_weights = torch.load('/kaggle/input/mobilenetv3/pytorch/default/1/MobileNetV3_Large_best_model_fold_5.pth')

# Apply the weights to the model
model.load_state_dict(best_model_weights)
# Out:
# /tmp/ipykernel_23/952454847.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model_weights = torch.load('/kaggle/input/mobilenetv3/pytorch/default/1/MobileNetV3_Large_best_model_fold_5.pth')
# <All keys matched successfully>

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
model = model.to(device)

# %% [markdown]
# # **Optimizer & LR**

# %%
criterion = nn.CrossEntropyLoss()

# Define the optimizer
optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5)

# %%
num_epochs = 5
desired_training_accuracy = 99.999
early_stopping_threshold = 3
early_stopping_counter = 0
best_val_loss = float('inf')

# %%
from sklearn.model_selection import StratifiedKFold

# Assume `dataset` is your PyTorch dataset
num_folds = 5
# Assuming train_dataset is your dataset
X = np.arange(len(train_dataset))  # Placeholder, you will index the dataset with this
y = np.array([label for _, label in train_dataset])  # Extract labels from the dataset

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)  # 5-Fold Cross-Validation

# %%
import time

start_time = time.time()

# %% [markdown]
# # **Training Loop**

# %%
# Lists to store the losses and accuracies for each fold
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    print(f'Fold {fold + 1}/{skf.n_splits}')
    
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)
    
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler)
    val_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=val_sampler)

    best_acc = 0  # Reset the best accuracy for each fold
    
    fold_train_losses = []
    fold_train_accuracies = []
    fold_val_losses = []
    fold_val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            if -1 in labels:
                continue  # Skip the batch if it contains dummy labels

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            _, predicted_train = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted_train == labels).sum().item()

            if i % 100 == 99:
                print(f'Epoch {epoch + 1}/{num_epochs}, Batch {i + 1}/{len(train_loader)}, '
                      f'Training Loss: {running_loss / 100}, Training Accuracy: {100 * correct_train / total_train}%')

        training_accuracy = correct_train / total_train
        fold_train_losses.append(running_loss / len(train_loader))
        fold_train_accuracies.append(training_accuracy)

        # Validation
        model.eval()
        val_running_loss = 0.0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for val_inputs, val_labels in val_loader:
                val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
                val_outputs = model(val_inputs)
                loss = criterion(val_outputs, val_labels)
                val_running_loss += loss.item()
                _, predicted_val = torch.max(val_outputs.data, 1)
                total_val += val_labels.size(0)
                correct_val += (predicted_val == val_labels).sum().item()

        validation_accuracy = correct_val / total_val
        validation_loss = val_running_loss / len(val_loader)
        fold_val_losses.append(validation_loss)
        fold_val_accuracies.append(validation_accuracy)

        print(f'Validation Accuracy after epoch {epoch + 1}/{num_epochs}: {100 * validation_accuracy}%')

        if validation_accuracy > best_acc:
            best_acc = validation_accuracy
            torch.save(model.state_dict(), f'best_model_fold_{fold + 1}.pth')

        scheduler.step(validation_loss)

    # Store metrics for the entire fold
    train_losses.extend(fold_train_losses)
    train_accuracies.extend(fold_train_accuracies)
    val_losses.extend(fold_val_losses)
    val_accuracies.extend(fold_val_accuracies)
# Out:
# Fold 1/5
# Epoch 1/5, Batch 100/1034, Training Loss: 3.4243316578865053, Training Accuracy: 99.09375%
# Epoch 1/5, Batch 200/1034, Training Loss: 6.856790459156036, Training Accuracy: 98.75%
# Epoch 1/5, Batch 300/1034, Training Loss: 10.287666325569154, Training Accuracy: 98.69791666666667%
# Epoch 1/5, Batch 400/1034, Training Loss: 13.717521448135376, Training Accuracy: 98.6875%
# Epoch 1/5, Batch 500/1034, Training Loss: 17.148545920848846, Training Accuracy: 98.675%
# Epoch 1/5, Batch 600/1034, Training Loss: 20.57860044002533, Training Accuracy: 98.66666666666667%
# Epoch 1/5, Batch 700/1034, Training Loss: 24.006219735145567, Training Accuracy: 98.69196428571429%
# Epoch 1/5, Batch 800/1034, Training Loss: 27.435759830474854, Training Accuracy: 98.69140625%
# Epoch 1/5, Batch 900/1034, Training Loss: 30.88857469558716, Training Accuracy: 98.42361111111111%
# Epoch 1/5, Batch 1000/1034, Training Loss: 34.32194409847259, Training Accuracy: 98.403125%
# Validation Accuracy after epoch 1/5: 97.77374470659407%
# Epoch 2/5, Batch 100/1034, Training Loss: 3.4338146209716798, Training Accuracy: 98.125%
# Epoch 2/5, Batch 200/1034, Training Loss: 6.861137106418609, Training Accuracy: 98.484375%
# Epoch 2/5, Batch 300/1034, Training Loss: 10.28477870941162, Training Accuracy: 98.73958333333333%
# Epoch 2/5, Batch 400/1034, Training Loss: 13.70907218694687, Training Accuracy: 98.84375%
# Epoch 2/5, Batch 500/1034, Training Loss: 17.14786054134369, Training Accuracy: 98.625%
# Epoch 2/5, Batch 600/1034, Training Loss: 20.57012818813324, Training Accuracy: 98.74479166666667%
# Epoch 2/5, Batch 700/1034, Training Loss: 23.998006677627565, Training Accuracy: 98.75%
# Epoch 2/5, Batch 800/1034, Training Loss: 27.429513812065125, Training Accuracy: 98.7265625%
# Epoch 2/5, Batch 900/1034, Training Loss: 30.860666015148162, Training Accuracy: 98.69791666666667%
# Epoch 2/5, Batch 1000/1034, Training Loss: 34.29002452135086, Training Accuracy: 98.696875%
# Validation Accuracy after epoch 2/5: 97.88263762855415%
# Epoch 3/5, Batch 100/1034, Training Loss: 3.4295259070396424, Training Accuracy: 98.625%
# Epoch 3/5, Batch 200/1034, Training Loss: 6.867579033374787, Training Accuracy: 98.1875%
# Epoch 3/5, Batch 300/1034, Training Loss: 10.304000580310822, Training Accuracy: 98.11458333333333%
# Epoch 3/5, Batch 400/1034, Training Loss: 13.738982722759246, Training Accuracy: 98.1171875%
# Epoch 3/5, Batch 500/1034, Training Loss: 17.1714417386055, Training Accuracy: 98.15625%
# Epoch 3/5, Batch 600/1034, Training Loss: 20.601410410404206, Training Accuracy: 98.22395833333333%
# Epoch 3/5, Batch 700/1034, Training Loss: 24.030151586532593, Training Accuracy: 98.29910714285714%
# Epoch 3/5, Batch 800/1034, Training Loss: 27.453228554725648, Training Accuracy: 98.41796875%
# Epoch 3/5, Batch 900/1034, Training Loss: 30.87604625940323, Training Accuracy: 98.51736111111111%
# Epoch 3/5, Batch 1000/1034, Training Loss: 34.29899420976639, Training Accuracy: 98.59375%
# Validation Accuracy after epoch 3/5: 91.68784029038113%
# Epoch 4/5, Batch 100/1034, Training Loss: 3.428291347026825, Training Accuracy: 98.84375%
# Epoch 4/5, Batch 200/1034, Training Loss: 6.859890530109405, Training Accuracy: 98.625%
# Epoch 4/5, Batch 300/1034, Training Loss: 10.295213949680328, Training Accuracy: 98.45833333333333%
# Epoch 4/5, Batch 400/1034, Training Loss: 13.732072510719298, Training Accuracy: 98.3203125%
# Epoch 4/5, Batch 500/1034, Training Loss: 17.16438995838165, Training Accuracy: 98.325%
# Epoch 4/5, Batch 600/1034, Training Loss: 20.602193253040312, Training Accuracy: 98.234375%
# Epoch 4/5, Batch 700/1034, Training Loss: 24.037577011585235, Training Accuracy: 98.21428571428571%
# Epoch 4/5, Batch 800/1034, Training Loss: 27.463777508735657, Training Accuracy: 98.3125%
# Epoch 4/5, Batch 900/1034, Training Loss: 30.888064475059508, Training Accuracy: 98.40625%
# Epoch 4/5, Batch 1000/1034, Training Loss: 34.313597192764284, Training Accuracy: 98.465625%
# Validation Accuracy after epoch 4/5: 99.3708408953418%
# Epoch 5/5, Batch 100/1034, Training Loss: 3.4281818532943724, Training Accuracy: 98.78125%
# Epoch 5/5, Batch 200/1034, Training Loss: 6.855536298751831, Training Accuracy: 98.796875%
# Epoch 5/5, Batch 300/1034, Training Loss: 10.284002130031586, Training Accuracy: 98.80208333333333%
# Epoch 5/5, Batch 400/1034, Training Loss: 13.710343861579895, Training Accuracy: 98.8359375%
# Epoch 5/5, Batch 500/1034, Training Loss: 17.143275566101075, Training Accuracy: 98.74375%
# Epoch 5/5, Batch 600/1034, Training Loss: 20.567559332847594, Training Accuracy: 98.8125%
# Epoch 5/5, Batch 700/1034, Training Loss: 23.989090089797973, Training Accuracy: 98.89732142857143%
# Epoch 5/5, Batch 800/1034, Training Loss: 27.41387869596481, Training Accuracy: 98.921875%
# Epoch 5/5, Batch 900/1034, Training Loss: 30.841004147529603, Training Accuracy: 98.91666666666667%
# Epoch 5/5, Batch 1000/1034, Training Loss: 34.26505722284317, Training Accuracy: 98.940625%
# Validation Accuracy after epoch 5/5: 97.71324863883848%
# Fold 2/5
# Epoch 1/5, Batch 100/1034, Training Loss: 3.4333325147628786, Training Accuracy: 98.28125%
# Epoch 1/5, Batch 200/1034, Training Loss: 6.857308192253113, Training Accuracy: 98.734375%
# Epoch 1/5, Batch 300/1034, Training Loss: 10.284610698223114, Training Accuracy: 98.77083333333333%
# Epoch 1/5, Batch 400/1034, Training Loss: 13.715319738388061, Training Accuracy: 98.6953125%
# Epoch 1/5, Batch 500/1034, Training Loss: 17.140621354579924, Training Accuracy: 98.7625%
# Epoch 1/5, Batch 600/1034, Training Loss: 20.564146399497986, Training Accuracy: 98.83854166666667%
# Epoch 1/5, Batch 700/1034, Training Loss: 23.99508234024048, Training Accuracy: 98.79464285714286%
# Epoch 1/5, Batch 800/1034, Training Loss: 27.426638629436493, Training Accuracy: 98.75390625%
# Epoch 1/5, Batch 900/1034, Training Loss: 30.861648614406587, Training Accuracy: 98.67708333333333%
# Epoch 1/5, Batch 1000/1034, Training Loss: 34.29325394630432, Training Accuracy: 98.653125%
# Validation Accuracy after epoch 1/5: 97.54385964912281%
# Epoch 2/5, Batch 100/1034, Training Loss: 3.430633933544159, Training Accuracy: 98.46875%
# Epoch 2/5, Batch 200/1034, Training Loss: 6.85540768623352, Training Accuracy: 98.78125%
# Epoch 2/5, Batch 300/1034, Training Loss: 10.277757642269135, Training Accuracy: 98.95833333333333%
# Epoch 2/5, Batch 400/1034, Training Loss: 13.702180581092835, Training Accuracy: 98.9921875%
# Epoch 2/5, Batch 500/1034, Training Loss: 17.12472531080246, Training Accuracy: 99.05625%
# Epoch 2/5, Batch 600/1034, Training Loss: 20.549459598064423, Training Accuracy: 99.0625%
# Epoch 2/5, Batch 700/1034, Training Loss: 23.978854670524598, Training Accuracy: 99.0%
# Epoch 2/5, Batch 800/1034, Training Loss: 27.40945011138916, Training Accuracy: 98.94921875%
# Epoch 2/5, Batch 900/1034, Training Loss: 30.833971908092497, Training Accuracy: 98.96875%
# Epoch 2/5, Batch 1000/1034, Training Loss: 34.259350869655606, Training Accuracy: 98.975%
# Validation Accuracy after epoch 2/5: 99.52813067150636%
# Epoch 3/5, Batch 100/1034, Training Loss: 3.422323751449585, Training Accuracy: 99.3125%
# Epoch 3/5, Batch 200/1034, Training Loss: 6.847346203327179, Training Accuracy: 99.203125%
# Epoch 3/5, Batch 300/1034, Training Loss: 10.275186460018158, Training Accuracy: 99.05208333333333%
# Epoch 3/5, Batch 400/1034, Training Loss: 13.700693247318268, Training Accuracy: 99.0390625%
# Epoch 3/5, Batch 500/1034, Training Loss: 17.132335286140442, Training Accuracy: 98.91875%
# Epoch 3/5, Batch 600/1034, Training Loss: 20.561389021873474, Training Accuracy: 98.875%
# Epoch 3/5, Batch 700/1034, Training Loss: 23.98949849843979, Training Accuracy: 98.86160714285714%
# Epoch 3/5, Batch 800/1034, Training Loss: 27.415107316970825, Training Accuracy: 98.87890625%
# Epoch 3/5, Batch 900/1034, Training Loss: 30.845358970165254, Training Accuracy: 98.83680555555556%
# Epoch 3/5, Batch 1000/1034, Training Loss: 34.27310179948807, Training Accuracy: 98.8375%
# Validation Accuracy after epoch 3/5: 97.79794313369631%
# Epoch 4/5, Batch 100/1034, Training Loss: 3.4274694323539734, Training Accuracy: 98.8125%
# Epoch 4/5, Batch 200/1034, Training Loss: 6.851819739341736, Training Accuracy: 98.984375%
# Epoch 4/5, Batch 300/1034, Training Loss: 10.276357288360595, Training Accuracy: 99.02083333333333%
# Epoch 4/5, Batch 400/1034, Training Loss: 13.700893304347993, Training Accuracy: 99.0546875%
# Epoch 4/5, Batch 500/1034, Training Loss: 17.12588609933853, Training Accuracy: 99.06875%
# Epoch 4/5, Batch 600/1034, Training Loss: 20.55046064376831, Training Accuracy: 99.078125%
# Epoch 4/5, Batch 700/1034, Training Loss: 23.978303334712983, Training Accuracy: 99.03571428571429%
# Epoch 4/5, Batch 800/1034, Training Loss: 27.40097991466522, Training Accuracy: 99.06640625%
# Epoch 4/5, Batch 900/1034, Training Loss: 30.82815771818161, Training Accuracy: 99.04861111111111%
# Epoch 4/5, Batch 1000/1034, Training Loss: 34.25811142921448, Training Accuracy: 99.0%
# Validation Accuracy after epoch 4/5: 99.51603145795524%
# Epoch 5/5, Batch 100/1034, Training Loss: 3.4228741192817687, Training Accuracy: 99.3125%
# Epoch 5/5, Batch 200/1034, Training Loss: 6.8471293592453, Training Accuracy: 99.25%
# Epoch 5/5, Batch 300/1034, Training Loss: 10.275129914283752, Training Accuracy: 99.08333333333333%
# Epoch 5/5, Batch 400/1034, Training Loss: 13.699717090129852, Training Accuracy: 99.0859375%
# Epoch 5/5, Batch 500/1034, Training Loss: 17.122298579216004, Training Accuracy: 99.13125%
# Epoch 5/5, Batch 600/1034, Training Loss: 20.543059084415436, Training Accuracy: 99.1875%
# Epoch 5/5, Batch 700/1034, Training Loss: 23.969716148376463, Training Accuracy: 99.14285714285714%
# Epoch 5/5, Batch 800/1034, Training Loss: 27.395778193473816, Training Accuracy: 99.125%
# Epoch 5/5, Batch 900/1034, Training Loss: 30.824153838157653, Training Accuracy: 99.08680555555556%
# Epoch 5/5, Batch 1000/1034, Training Loss: 34.248892629146575, Training Accuracy: 99.0875%
# Validation Accuracy after epoch 5/5: 99.45553539019963%
# Fold 3/5
# Epoch 1/5, Batch 100/1034, Training Loss: 3.4244737148284914, Training Accuracy: 99.125%
# Epoch 1/5, Batch 200/1034, Training Loss: 6.844766030311584, Training Accuracy: 99.328125%
# Epoch 1/5, Batch 300/1034, Training Loss: 10.265858345031738, Training Accuracy: 99.36458333333333%
# Epoch 1/5, Batch 400/1034, Training Loss: 13.685562858581543, Training Accuracy: 99.421875%
# Epoch 1/5, Batch 500/1034, Training Loss: 17.108978304862976, Training Accuracy: 99.375%
# Epoch 1/5, Batch 600/1034, Training Loss: 20.53265216588974, Training Accuracy: 99.34375%
# Epoch 1/5, Batch 700/1034, Training Loss: 23.95524581193924, Training Accuracy: 99.33928571428571%
# Epoch 1/5, Batch 800/1034, Training Loss: 27.37791170835495, Training Accuracy: 99.33203125%
# Epoch 1/5, Batch 900/1034, Training Loss: 30.799596009254454, Training Accuracy: 99.33680555555556%
# Epoch 1/5, Batch 1000/1034, Training Loss: 34.22204869270325, Training Accuracy: 99.334375%
# Validation Accuracy after epoch 1/5: 99.35866408518878%
# Epoch 2/5, Batch 100/1034, Training Loss: 3.427139575481415, Training Accuracy: 98.84375%
# Epoch 2/5, Batch 200/1034, Training Loss: 6.851741337776184, Training Accuracy: 98.96875%
# Epoch 2/5, Batch 300/1034, Training Loss: 10.272953600883485, Training Accuracy: 99.125%
# Epoch 2/5, Batch 400/1034, Training Loss: 13.69602488040924, Training Accuracy: 99.1484375%
# Epoch 2/5, Batch 500/1034, Training Loss: 17.115384333133697, Training Accuracy: 99.24375%
# Epoch 2/5, Batch 600/1034, Training Loss: 20.534884197711946, Training Accuracy: 99.30208333333333%
# Epoch 2/5, Batch 700/1034, Training Loss: 23.960370662212373, Training Accuracy: 99.26339285714286%
# Epoch 2/5, Batch 800/1034, Training Loss: 27.3801433467865, Training Accuracy: 99.30078125%
# Epoch 2/5, Batch 900/1034, Training Loss: 30.800583832263946, Training Accuracy: 99.32291666666667%
# Epoch 2/5, Batch 1000/1034, Training Loss: 34.22419213056564, Training Accuracy: 99.309375%
# Validation Accuracy after epoch 2/5: 99.38286544046466%
# Epoch 3/5, Batch 100/1034, Training Loss: 3.4202665972709654, Training Accuracy: 99.53125%
# Epoch 3/5, Batch 200/1034, Training Loss: 6.840020010471344, Training Accuracy: 99.5625%
# Epoch 3/5, Batch 300/1034, Training Loss: 10.26188005208969, Training Accuracy: 99.48958333333333%
# Epoch 3/5, Batch 400/1034, Training Loss: 13.688654713630676, Training Accuracy: 99.328125%
# Epoch 3/5, Batch 500/1034, Training Loss: 17.110713481903076, Training Accuracy: 99.33125%
# Epoch 3/5, Batch 600/1034, Training Loss: 20.53121777534485, Training Accuracy: 99.359375%
# Epoch 3/5, Batch 700/1034, Training Loss: 23.955185055732727, Training Accuracy: 99.32589285714286%
# Epoch 3/5, Batch 800/1034, Training Loss: 27.376439917087556, Training Accuracy: 99.3359375%
# Epoch 3/5, Batch 900/1034, Training Loss: 30.797555222511292, Training Accuracy: 99.35069444444444%
# Epoch 3/5, Batch 1000/1034, Training Loss: 34.22335489273071, Training Accuracy: 99.3125%
# Validation Accuracy after epoch 3/5: 99.31026137463698%
# Epoch 4/5, Batch 100/1034, Training Loss: 3.4243161916732787, Training Accuracy: 99.125%
# Epoch 4/5, Batch 200/1034, Training Loss: 6.845431463718414, Training Accuracy: 99.28125%
# Epoch 4/5, Batch 300/1034, Training Loss: 10.26600849866867, Training Accuracy: 99.34375%
# Epoch 4/5, Batch 400/1034, Training Loss: 13.687800862789153, Training Accuracy: 99.359375%
# Epoch 4/5, Batch 500/1034, Training Loss: 17.10856082201004, Training Accuracy: 99.38125%
# Epoch 4/5, Batch 600/1034, Training Loss: 20.5309303689003, Training Accuracy: 99.36979166666667%
# Epoch 4/5, Batch 700/1034, Training Loss: 23.953580536842345, Training Accuracy: 99.35714285714286%
# Epoch 4/5, Batch 800/1034, Training Loss: 27.37525988340378, Training Accuracy: 99.359375%
# Epoch 4/5, Batch 900/1034, Training Loss: 30.797341299057006, Training Accuracy: 99.35763888888889%
# Epoch 4/5, Batch 1000/1034, Training Loss: 34.21811976671219, Training Accuracy: 99.36875%
# Validation Accuracy after epoch 4/5: 99.35866408518878%
# Epoch 5/5, Batch 100/1034, Training Loss: 3.423369903564453, Training Accuracy: 99.21875%
# Epoch 5/5, Batch 200/1034, Training Loss: 6.844893887042999, Training Accuracy: 99.296875%
# Epoch 5/5, Batch 300/1034, Training Loss: 10.267576069831849, Training Accuracy: 99.29166666666667%
# Epoch 5/5, Batch 400/1034, Training Loss: 13.689227735996246, Training Accuracy: 99.3125%
# Epoch 5/5, Batch 500/1034, Training Loss: 17.109062552452087, Training Accuracy: 99.3625%
# Epoch 5/5, Batch 600/1034, Training Loss: 20.52858668088913, Training Accuracy: 99.40104166666667%
# Epoch 5/5, Batch 700/1034, Training Loss: 23.95120824098587, Training Accuracy: 99.38392857142857%
# Epoch 5/5, Batch 800/1034, Training Loss: 27.372458515167235, Training Accuracy: 99.38671875%
# Epoch 5/5, Batch 900/1034, Training Loss: 30.794778118133546, Training Accuracy: 99.37847222222223%
# Epoch 5/5, Batch 1000/1034, Training Loss: 34.217441368103025, Training Accuracy: 99.36875%
# Validation Accuracy after epoch 5/5: 99.37076476282671%
# Fold 4/5
# Epoch 1/5, Batch 100/1034, Training Loss: 3.4198204112052917, Training Accuracy: 99.5625%
# Epoch 1/5, Batch 200/1034, Training Loss: 6.842482886314392, Training Accuracy: 99.421875%
# Epoch 1/5, Batch 300/1034, Training Loss: 10.263246598243713, Training Accuracy: 99.4375%
# Epoch 1/5, Batch 400/1034, Training Loss: 13.685413081645965, Training Accuracy: 99.4140625%
# Epoch 1/5, Batch 500/1034, Training Loss: 17.107402379512788, Training Accuracy: 99.4%
# Epoch 1/5, Batch 600/1034, Training Loss: 20.528174443244936, Training Accuracy: 99.41145833333333%
# Epoch 1/5, Batch 700/1034, Training Loss: 23.94930806159973, Training Accuracy: 99.41517857142857%
# Epoch 1/5, Batch 800/1034, Training Loss: 27.371049942970277, Training Accuracy: 99.41015625%
# Epoch 1/5, Batch 900/1034, Training Loss: 30.792164919376372, Training Accuracy: 99.41319444444444%
# Epoch 1/5, Batch 1000/1034, Training Loss: 34.215140714645386, Training Accuracy: 99.396875%
# Validation Accuracy after epoch 1/5: 99.4433688286544%
# Epoch 2/5, Batch 100/1034, Training Loss: 3.4216954469680787, Training Accuracy: 99.375%
# Epoch 2/5, Batch 200/1034, Training Loss: 6.844030275344848, Training Accuracy: 99.34375%
# Epoch 2/5, Batch 300/1034, Training Loss: 10.263847796916961, Training Accuracy: 99.41666666666667%
# Epoch 2/5, Batch 400/1034, Training Loss: 13.685016593933106, Training Accuracy: 99.421875%
# Epoch 2/5, Batch 500/1034, Training Loss: 17.106481659412385, Training Accuracy: 99.41875%
# Epoch 2/5, Batch 600/1034, Training Loss: 20.527163491249084, Training Accuracy: 99.42708333333333%
# Epoch 2/5, Batch 700/1034, Training Loss: 23.95017954826355, Training Accuracy: 99.40178571428571%
# Epoch 2/5, Batch 800/1034, Training Loss: 27.37283557653427, Training Accuracy: 99.38671875%
# Epoch 2/5, Batch 900/1034, Training Loss: 30.793760695457458, Training Accuracy: 99.39236111111111%
# Epoch 2/5, Batch 1000/1034, Training Loss: 34.21607785224914, Training Accuracy: 99.384375%
# Validation Accuracy after epoch 2/5: 99.4433688286544%
# Epoch 3/5, Batch 100/1034, Training Loss: 3.4202138948440552, Training Accuracy: 99.53125%
# Epoch 3/5, Batch 200/1034, Training Loss: 6.843563048839569, Training Accuracy: 99.375%
# Epoch 3/5, Batch 300/1034, Training Loss: 10.265889492034912, Training Accuracy: 99.35416666666667%
# Epoch 3/5, Batch 400/1034, Training Loss: 13.686956930160523, Training Accuracy: 99.375%
# Epoch 3/5, Batch 500/1034, Training Loss: 17.108971796035767, Training Accuracy: 99.36875%
# Epoch 3/5, Batch 600/1034, Training Loss: 20.529728136062623, Training Accuracy: 99.38541666666667%
# Epoch 3/5, Batch 700/1034, Training Loss: 23.950218048095703, Training Accuracy: 99.40178571428571%
# Epoch 3/5, Batch 800/1034, Training Loss: 27.37224467754364, Training Accuracy: 99.39453125%
# Epoch 3/5, Batch 900/1034, Training Loss: 30.7950185751915, Training Accuracy: 99.38194444444444%
# Epoch 3/5, Batch 1000/1034, Training Loss: 34.215148057937625, Training Accuracy: 99.396875%
# Validation Accuracy after epoch 3/5: 99.4433688286544%
# Epoch 4/5, Batch 100/1034, Training Loss: 3.426072824001312, Training Accuracy: 98.9375%
# Epoch 4/5, Batch 200/1034, Training Loss: 6.846829788684845, Training Accuracy: 99.203125%
# Epoch 4/5, Batch 300/1034, Training Loss: 10.266647887229919, Training Accuracy: 99.32291666666667%
# Epoch 4/5, Batch 400/1034, Training Loss: 13.686196298599244, Training Accuracy: 99.390625%
# Epoch 4/5, Batch 500/1034, Training Loss: 17.10792898654938, Training Accuracy: 99.3875%
# Epoch 4/5, Batch 600/1034, Training Loss: 20.527105283737182, Training Accuracy: 99.42708333333333%
# Epoch 4/5, Batch 700/1034, Training Loss: 23.951297521591187, Training Accuracy: 99.38392857142857%
# Epoch 4/5, Batch 800/1034, Training Loss: 27.373037333488465, Training Accuracy: 99.3828125%
# Epoch 4/5, Batch 900/1034, Training Loss: 30.793565311431884, Training Accuracy: 99.39583333333333%
# Epoch 4/5, Batch 1000/1034, Training Loss: 34.215261533260346, Training Accuracy: 99.39375%
# Validation Accuracy after epoch 4/5: 99.43126815101647%
# Epoch 5/5, Batch 100/1034, Training Loss: 3.4204442429542543, Training Accuracy: 99.5%
# Epoch 5/5, Batch 200/1034, Training Loss: 6.841871359348297, Training Accuracy: 99.453125%
# Epoch 5/5, Batch 300/1034, Training Loss: 10.262002923488616, Training Accuracy: 99.47916666666667%
# Epoch 5/5, Batch 400/1034, Training Loss: 13.685063087940216, Training Accuracy: 99.421875%
# Epoch 5/5, Batch 500/1034, Training Loss: 17.10738910675049, Training Accuracy: 99.4%
# Epoch 5/5, Batch 600/1034, Training Loss: 20.529085280895234, Training Accuracy: 99.39583333333333%
# Epoch 5/5, Batch 700/1034, Training Loss: 23.95140238046646, Training Accuracy: 99.38392857142857%
# Epoch 5/5, Batch 800/1034, Training Loss: 27.37622848749161, Training Accuracy: 99.34375%
# Epoch 5/5, Batch 900/1034, Training Loss: 30.796046895980837, Training Accuracy: 99.36805555555556%
# Epoch 5/5, Batch 1000/1034, Training Loss: 34.216489341259006, Training Accuracy: 99.38125%
# Validation Accuracy after epoch 5/5: 99.4433688286544%
# Fold 5/5
# Epoch 1/5, Batch 100/1034, Training Loss: 3.420447840690613, Training Accuracy: 99.5%
# Epoch 1/5, Batch 200/1034, Training Loss: 6.841831612586975, Training Accuracy: 99.453125%
# Epoch 1/5, Batch 300/1034, Training Loss: 10.263526136875152, Training Accuracy: 99.42708333333333%
# Epoch 1/5, Batch 400/1034, Training Loss: 13.684595158100128, Training Accuracy: 99.4296875%
# Epoch 1/5, Batch 500/1034, Training Loss: 17.105976541042327, Training Accuracy: 99.425%
# Epoch 1/5, Batch 600/1034, Training Loss: 20.527196881771086, Training Accuracy: 99.42708333333333%
# Epoch 1/5, Batch 700/1034, Training Loss: 23.945386865139007, Training Accuracy: 99.46875%
# Epoch 1/5, Batch 800/1034, Training Loss: 27.367142164707182, Training Accuracy: 99.45703125%
# Epoch 1/5, Batch 900/1034, Training Loss: 30.789167330265045, Training Accuracy: 99.44444444444444%
# Epoch 1/5, Batch 1000/1034, Training Loss: 34.21195570230484, Training Accuracy: 99.425%
# Validation Accuracy after epoch 1/5: 99.28606001936109%
# Epoch 2/5, Batch 100/1034, Training Loss: 3.4209691643714906, Training Accuracy: 99.4375%
# Epoch 2/5, Batch 200/1034, Training Loss: 6.84079313993454, Training Accuracy: 99.5%
# Epoch 2/5, Batch 300/1034, Training Loss: 10.264127542972565, Training Accuracy: 99.40625%
# Epoch 2/5, Batch 400/1034, Training Loss: 13.685828642845154, Training Accuracy: 99.3984375%
# Epoch 2/5, Batch 500/1034, Training Loss: 17.1044180727005, Training Accuracy: 99.45625%
# Epoch 2/5, Batch 600/1034, Training Loss: 20.525797686576844, Training Accuracy: 99.44791666666667%
# Epoch 2/5, Batch 700/1034, Training Loss: 23.948119158744813, Training Accuracy: 99.42857142857143%
# Epoch 2/5, Batch 800/1034, Training Loss: 27.369499263763426, Training Accuracy: 99.42578125%
# Epoch 2/5, Batch 900/1034, Training Loss: 30.7905686044693, Training Accuracy: 99.42708333333333%
# Epoch 2/5, Batch 1000/1034, Training Loss: 34.211785509586335, Training Accuracy: 99.428125%
# Validation Accuracy after epoch 2/5: 99.28606001936109%
# Epoch 3/5, Batch 100/1034, Training Loss: 3.4210672259330748, Training Accuracy: 99.4375%
# Epoch 3/5, Batch 200/1034, Training Loss: 6.842761383056641, Training Accuracy: 99.40625%
# Epoch 3/5, Batch 300/1034, Training Loss: 10.264143669605255, Training Accuracy: 99.40625%
# Epoch 3/5, Batch 400/1034, Training Loss: 13.684288980960845, Training Accuracy: 99.4375%
# Epoch 3/5, Batch 500/1034, Training Loss: 17.10318734407425, Training Accuracy: 99.48125%
# Epoch 3/5, Batch 600/1034, Training Loss: 20.523884418010713, Training Accuracy: 99.47916666666667%
# Epoch 3/5, Batch 700/1034, Training Loss: 23.947142279148103, Training Accuracy: 99.44196428571429%
# Epoch 3/5, Batch 800/1034, Training Loss: 27.370120565891266, Training Accuracy: 99.41796875%
# Epoch 3/5, Batch 900/1034, Training Loss: 30.789636557102202, Training Accuracy: 99.4375%
# Epoch 3/5, Batch 1000/1034, Training Loss: 34.21071118354797, Training Accuracy: 99.4375%
# Validation Accuracy after epoch 3/5: 99.28606001936109%
# Epoch 4/5, Batch 100/1034, Training Loss: 3.4210870480537414, Training Accuracy: 99.4375%
# Epoch 4/5, Batch 200/1034, Training Loss: 6.84246731042862, Training Accuracy: 99.421875%
# Epoch 4/5, Batch 300/1034, Training Loss: 10.263545882701873, Training Accuracy: 99.42708333333333%
# Epoch 4/5, Batch 400/1034, Training Loss: 13.683992605209351, Training Accuracy: 99.4453125%
# Epoch 4/5, Batch 500/1034, Training Loss: 17.105387575626374, Training Accuracy: 99.4375%
# Epoch 4/5, Batch 600/1034, Training Loss: 20.52614250421524, Training Accuracy: 99.44270833333333%
# Epoch 4/5, Batch 700/1034, Training Loss: 23.947525889873504, Training Accuracy: 99.4375%
# Epoch 4/5, Batch 800/1034, Training Loss: 27.36796788930893, Training Accuracy: 99.4453125%
# Epoch 4/5, Batch 900/1034, Training Loss: 30.789381034374237, Training Accuracy: 99.44097222222223%
# Epoch 4/5, Batch 1000/1034, Training Loss: 34.21107450246811, Training Accuracy: 99.434375%
# Validation Accuracy after epoch 4/5: 99.28606001936109%
# Epoch 5/5, Batch 100/1034, Training Loss: 3.4198182582855225, Training Accuracy: 99.5625%
# Epoch 5/5, Batch 200/1034, Training Loss: 6.840260393619538, Training Accuracy: 99.53125%
# Epoch 5/5, Batch 300/1034, Training Loss: 10.260077447891236, Training Accuracy: 99.54166666666667%
# Epoch 5/5, Batch 400/1034, Training Loss: 13.681146869659424, Training Accuracy: 99.515625%
# Epoch 5/5, Batch 500/1034, Training Loss: 17.102860596179962, Training Accuracy: 99.4875%
# Epoch 5/5, Batch 600/1034, Training Loss: 20.523336420059206, Training Accuracy: 99.48958333333333%
# Epoch 5/5, Batch 700/1034, Training Loss: 23.945434038639068, Training Accuracy: 99.46875%
# Epoch 5/5, Batch 800/1034, Training Loss: 27.37056503534317, Training Accuracy: 99.4140625%
# Epoch 5/5, Batch 900/1034, Training Loss: 30.793507883548738, Training Accuracy: 99.39583333333333%
# Epoch 5/5, Batch 1000/1034, Training Loss: 34.21213722467422, Training Accuracy: 99.425%
# Validation Accuracy after epoch 5/5: 99.28606001936109%

# %% [markdown]
# # **Training Time**

# %%
end_time = time.time()

duration_seconds = end_time - start_time
duration_minutes = duration_seconds / 60

print("Training duration: {:.2f} minutes".format(duration_minutes))
# Out:
# Training duration: 112.97 minutes

# %% [markdown]
# # **Plotting Training&Validation**

# %%
# Plotting Training and Validation Losses
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plotting Training and Validation Accuracies
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # **Picking best model**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# %%
import torch
from sklearn.metrics import precision_score, recall_score, f1_score

# Check if CUDA (GPU) is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the paths for each fold
model_paths = [
    '/kaggle/working/best_model_fold_1.pth',
    '/kaggle/working/best_model_fold_2.pth',
    '/kaggle/working/best_model_fold_3.pth',
    '/kaggle/working/best_model_fold_4.pth',
    '/kaggle/working/best_model_fold_5.pth'
]

# Placeholder for the best model and best performance
best_model = None
best_f1_score = float('-inf')  # If maximizing F1-score. Change to float('inf') if minimizing.

# Function to evaluate the model and calculate metrics on a given dataset (validation or test)
def evaluate_model(model, loader):
    model.eval()  # Set model to evaluation mode
    all_preds = []
    all_labels = []
    correct = 0
    total = 0

    # Disable gradient computation for evaluation
    with torch.no_grad():
        for inputs, labels in loader:  # Loop through the DataLoader (val_loader or test_loader)
            # Move inputs and labels to the same device as the model
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)
            
            # Get the predicted class
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # Calculate accuracy
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    # Calculate Precision, Recall, F1-Score, and Accuracy
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')
    accuracy = correct / total  # Accuracy = correct predictions / total predictions

    return precision, recall, f1, accuracy

# Iterate over each model, load it, and evaluate it on both validation and test sets
for path in model_paths:
    model.load_state_dict(torch.load(path))  # Load model weights
    model.to(device)  # Move model to the selected device (CPU or GPU)

    # Evaluate on validation set
    val_precision, val_recall, val_f1, val_accuracy = evaluate_model(model, val_loader)
    print(f'Model {path} - Validation Precision: {val_precision}, Validation Recall: {val_recall}, Validation F1-Score: {val_f1}, Validation Accuracy: {val_accuracy}')

    # Evaluate on test set
    test_precision, test_recall, test_f1, test_accuracy = evaluate_model(model, test_loader)
    print(f'Model {path} - Test Precision: {test_precision}, Test Recall: {test_recall}, Test F1-Score: {test_f1}, Test Accuracy: {test_accuracy}')

    # Update the best model if F1-Score on validation is better
    if val_f1 > best_f1_score:
        best_f1_score = val_f1
        best_model = model

print(f'The best model is from: {model_paths[model_paths.index(path)]} with Validation F1-Score: {best_f1_score}')
# Out:
# /tmp/ipykernel_23/2467421346.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(path))  # Load model weights
# Model /kaggle/working/best_model_fold_1.pth - Validation Precision: 0.994888544382885, Validation Recall: 0.994610079971632, Validation F1-Score: 0.9935948583498633, Validation Accuracy: 0.9923765730880929
# Model /kaggle/working/best_model_fold_1.pth - Test Precision: 0.9933734769614302, Test Recall: 0.9933918147749081, Test F1-Score: 0.9925143800058548, Test Accuracy: 0.9914967211933415
# /tmp/ipykernel_23/2467421346.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(path))  # Load model weights
# Model /kaggle/working/best_model_fold_2.pth - Validation Precision: 0.9950157931873824, Validation Recall: 0.9946670026035105, Validation F1-Score: 0.9936882857283508, Validation Accuracy: 0.9924975798644724
# Model /kaggle/working/best_model_fold_2.pth - Test Precision: 0.9937047575741311, Test Recall: 0.9936287820649942, Test F1-Score: 0.9928147777371881, Test Accuracy: 0.9918570296173524
# /tmp/ipykernel_23/2467421346.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(path))  # Load model weights
# Model /kaggle/working/best_model_fold_3.pth - Validation Precision: 0.995389904672605, Validation Recall: 0.9950449315528681, Validation F1-Score: 0.994066224515765, Validation Accuracy: 0.9928606001936109
# Model /kaggle/working/best_model_fold_3.pth - Test Precision: 0.9950264371167961, Test Recall: 0.9950118979380335, Test F1-Score: 0.9941878016127175, Test Accuracy: 0.9932262016285941
# /tmp/ipykernel_23/2467421346.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(path))  # Load model weights
# Model /kaggle/working/best_model_fold_4.pth - Validation Precision: 0.995389904672605, Validation Recall: 0.9950449315528681, Validation F1-Score: 0.994066224515765, Validation Accuracy: 0.9928606001936109
# Model /kaggle/working/best_model_fold_4.pth - Test Precision: 0.995590797300199, Test Recall: 0.9956598450411099, Test F1-Score: 0.994800606729385, Test Accuracy: 0.9938026951070116
# /tmp/ipykernel_23/2467421346.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(path))  # Load model weights
# Model /kaggle/working/best_model_fold_5.pth - Validation Precision: 0.995389904672605, Validation Recall: 0.9950449315528681, Validation F1-Score: 0.994066224515765, Validation Accuracy: 0.9928606001936109
# Model /kaggle/working/best_model_fold_5.pth - Test Precision: 0.9955907973001992, Test Recall: 0.9956589380708623, Test F1-Score: 0.994800150483221, Test Accuracy: 0.9938026951070116
# The best model is from: /kaggle/working/best_model_fold_5.pth with Validation F1-Score: 0.994066224515765

# %%
def evaluate_model(best_model, test_loader, device):
    best_model.eval()  # Set model to evaluation mode
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_accuracy = correct / total
    print(f'Test Accuracy: {100 * test_accuracy}%')

    return test_accuracy

# %%
test_accuracy = evaluate_model(best_model, test_loader, device)
# Out:
# Test Accuracy: 99.38026951070115%

# %%
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score


best_model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Calculate metrics
print("Classification Report:")
print(classification_report(all_labels, all_preds))

print("Confusion Matrix:")
print(confusion_matrix(all_labels, all_preds))

precision = precision_score(all_labels, all_preds, average='weighted')
print(f'Precision: {precision:.4f}')

recall = recall_score(all_labels, all_preds, average='weighted')
print(f'Recall: {recall:.4f}')

f1 = f1_score(all_labels, all_preds, average='weighted')
print(f'F1 Score: {f1:.4f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       164
#            1       1.00      0.99      1.00       164
#            2       1.00      1.00      1.00       164
#            3       1.00      1.00      1.00       161
#            4       1.00      1.00      1.00       164
#            5       1.00      1.00      1.00       164
#            6       1.00      1.00      1.00       164
#            7       1.00      1.00      1.00       144
#            8       1.00      1.00      1.00       166
#            9       1.00      1.00      1.00       164
#           10       1.00      1.00      1.00       164
#           11       1.00      1.00      1.00       143
#           12       0.98      1.00      0.99       166
#           13       1.00      1.00      1.00       166
#           14       1.00      1.00      1.00       166
#           15       1.00      1.00      1.00       166
#           16       1.00      1.00      1.00       164
#           17       1.00      1.00      1.00       164
#           18       1.00      1.00      1.00       166
#           19       0.67      1.00      0.80       164
#           20       1.00      0.67      0.80       246
#           21       1.00      1.00      1.00       246
#           22       1.00      1.00      1.00       164
#           23       1.00      1.00      1.00       164
#           24       1.00      1.00      1.00       164
#           25       1.00      1.00      1.00       166
#           26       1.00      1.00      1.00       166
#           27       1.00      1.00      1.00       166
#           28       1.00      1.00      1.00       166
#           29       1.00      1.00      1.00       164
#           30       1.00      1.00      1.00       166
#           31       1.00      1.00      1.00       166
#           32       1.00      1.00      1.00       166
#           33       1.00      1.00      1.00       164
#           34       1.00      1.00      1.00       166
#           35       1.00      1.00      1.00       166
#           36       1.00      1.00      1.00       166
#           37       1.00      1.00      1.00       156
#           38       1.00      1.00      1.00       166
#           39       1.00      1.00      1.00       164
#           40       1.00      1.00      1.00       166
#           41       1.00      1.00      1.00       166
#           42       1.00      1.00      1.00       166
#           43       1.00      1.00      1.00       166
#           44       1.00      1.00      1.00       166
#           45       1.00      1.00      1.00       166
#           46       1.00      1.00      1.00       246
#           47       1.00      1.00      1.00       164
#           48       1.00      1.00      1.00       164
#           49       1.00      1.00      1.00       160
#           50       1.00      1.00      1.00       164
#           51       1.00      1.00      1.00       166
#           52       1.00      1.00      1.00       164
#           53       1.00      1.00      1.00       164
#           54       1.00      1.00      1.00       164
#           55       1.00      1.00      1.00       166
#           56       1.00      1.00      1.00       166
#           57       1.00      1.00      1.00       166
#           58       1.00      1.00      1.00       166
#           59       1.00      1.00      1.00       164
#           60       0.99      1.00      1.00       164
#           61       1.00      1.00      1.00       166
#           62       1.00      1.00      1.00       163
#           63       1.00      1.00      1.00       166
#           64       1.00      1.00      1.00       151
#           65       1.00      1.00      1.00       164
#           66       1.00      1.00      1.00       166
#           67       1.00      1.00      1.00       164
#           68       1.00      1.00      1.00       166
#           69       1.00      1.00      1.00       162
#           70       1.00      1.00      1.00       164
#           71       1.00      0.99      0.99       246
#           72       1.00      1.00      1.00       166
#           73       1.00      1.00      1.00       166
#           74       1.00      1.00      1.00       246
#           75       1.00      1.00      1.00       225
#           76       1.00      1.00      1.00       246
#           77       1.00      1.00      1.00       160
#           78       1.00      1.00      1.00       164
#           79       1.00      1.00      1.00       127
#           80       1.00      1.00      1.00       249
#
#     accuracy                           0.99     13877
#    macro avg       1.00      1.00      0.99     13877
# weighted avg       1.00      0.99      0.99     13877
#
# Confusion Matrix:
# [[164   0   0 ...   0   0   0]
#  [  0 163   0 ...   0   0   0]
#  [  0   0 164 ...   0   0   0]
#  ...
#  [  0   0   0 ... 164   0   0]
#  [  0   0   0 ...   0 127   0]
#  [  0   0   0 ...   0   0 249]]
# Precision: 0.9958
# Recall: 0.9938
# F1 Score: 0.9938

# %% [markdown]
# # **Explainable AI**

# %%
pip install torchcam
# Out:
# Collecting torchcam
#   Downloading torchcam-0.4.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from torchcam) (2.4.0)
# Requirement already satisfied: numpy<2.0.0,>=1.17.2 in /opt/conda/lib/python3.10/site-packages (from torchcam) (1.26.4)
# Requirement already satisfied: Pillow!=9.2.0,>=8.4.0 in /opt/conda/lib/python3.10/site-packages (from torchcam) (10.3.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from torchcam) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (2.9.0.post0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch<3.0.0,>=2.0.0->torchcam) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<3.0.0,>=2.0.0->torchcam) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch<3.0.0,>=2.0.0->torchcam) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.0->torchcam) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch<3.0.0,>=2.0.0->torchcam) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<3.0.0,>=2.0.0->torchcam) (1.3.0)
# Downloading torchcam-0.4.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: torchcam
# Successfully installed torchcam-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from torchcam.methods import GradCAM
from torchvision import models
import numpy as np

# %%
cam_extractor = GradCAM(model, target_layer='features.12')  # Try layer 12

# %%
# Function to denormalize the image for plotting
def denormalize(img, mean, std):
    mean = torch.tensor(mean).view(3, 1, 1).to(device)
    std = torch.tensor(std).view(3, 1, 1).to(device)
    img = img * std + mean
    return img.clamp(0, 1)

# %%
# Iterate over the test set
for i, (inputs, labels) in enumerate(test_loader):
    # Move the inputs and labels to the same device as the model
    inputs = inputs.to(device)
    labels = labels.to(device)

    # Forward pass (do not use torch.no_grad() here, since Grad-CAM needs gradients)
    outputs = best_model(inputs)

    # Get the predicted class (index [0] extracts the value from the tensor)
    predicted = outputs.argmax(dim=1)[0].item()

    # Extract the CAM for the predicted class
    activation_map = cam_extractor(predicted, outputs)

    # Average the activation map across the channel dimension to get a 2D heatmap
    heatmap = activation_map[0].mean(dim=0).cpu().numpy()

    # Plotting
    plt.figure(figsize=(10, 5))

    # Original image
    ax1 = plt.subplot(1, 3, 1)
    img = denormalize(inputs[0], [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    img = img.permute(1, 2, 0).cpu().numpy()  # Move the tensor back to CPU for plotting
    ax1.imshow(img)
    ax1.set_title(f'True: {test_dataset.classes[labels[0].item()]}')  # Extract the scalar value from labels
    ax1.axis('off')

    # Heatmap
    ax2 = plt.subplot(1, 3, 2)
    ax2.imshow(heatmap, cmap='jet')  # Display the 2D heatmap
    ax2.set_title('Grad-CAM Heatmap')
    ax2.axis('off')

    # Overlay the heatmap on the image
    ax3 = plt.subplot(1, 3, 3)
    ax3.imshow(img)
    ax3.imshow(heatmap, cmap='jet', alpha=0.5)  # Overlay with transparency
    ax3.set_title(f'Predicted: {test_dataset.classes[predicted]}')
    ax3.axis('off')

    plt.tight_layout()
    plt.show()

    # Stop after the first example for demonstration; remove this line to iterate over all
    if i == 0:
        break

# %%
cam_extractor = GradCAM(model, target_layer='features.14')  # Try layer 14

# %%
# Iterate over the test set
for i, (inputs, labels) in enumerate(test_loader):
    # Move the inputs and labels to the same device as the model
    inputs = inputs.to(device)
    labels = labels.to(device)

    # Forward pass (do not use torch.no_grad() here, since Grad-CAM needs gradients)
    outputs = best_model(inputs)

    # Get the predicted class (index [0] extracts the value from the tensor)
    predicted = outputs.argmax(dim=1)[0].item()

    # Extract the CAM for the predicted class
    activation_map = cam_extractor(predicted, outputs)

    # Average the activation map across the channel dimension to get a 2D heatmap
    heatmap = activation_map[0].mean(dim=0).cpu().numpy()

    # Plotting
    plt.figure(figsize=(10, 5))

    # Original image
    ax1 = plt.subplot(1, 3, 1)
    img = denormalize(inputs[0], [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    img = img.permute(1, 2, 0).cpu().numpy()  # Move the tensor back to CPU for plotting
    ax1.imshow(img)
    ax1.set_title(f'True: {test_dataset.classes[labels[0].item()]}')  # Extract the scalar value from labels
    ax1.axis('off')

    # Heatmap
    ax2 = plt.subplot(1, 3, 2)
    ax2.imshow(heatmap, cmap='jet')  # Display the 2D heatmap
    ax2.set_title('Grad-CAM Heatmap')
    ax2.axis('off')

    # Overlay the heatmap on the image
    ax3 = plt.subplot(1, 3, 3)
    ax3.imshow(img)
    ax3.imshow(heatmap, cmap='jet', alpha=0.5)  # Overlay with transparency
    ax3.set_title(f'Predicted: {test_dataset.classes[predicted]}')
    ax3.axis('off')

    plt.tight_layout()
    plt.show()

    # Stop after the first example for demonstration; remove this line to iterate over all
    if i == 0:
        break

# %%
cam_extractor = GradCAM(model, target_layer='features.16')  # Try layer 16

# %%
# Iterate over the test set
for i, (inputs, labels) in enumerate(test_loader):
    # Move the inputs and labels to the same device as the model
    inputs = inputs.to(device)
    labels = labels.to(device)

    # Forward pass (do not use torch.no_grad() here, since Grad-CAM needs gradients)
    outputs = best_model(inputs)

    # Get the predicted class (index [0] extracts the value from the tensor)
    predicted = outputs.argmax(dim=1)[0].item()

    # Extract the CAM for the predicted class
    activation_map = cam_extractor(predicted, outputs)

    # Average the activation map across the channel dimension to get a 2D heatmap
    heatmap = activation_map[0].mean(dim=0).cpu().numpy()

    # Plotting
    plt.figure(figsize=(10, 5))

    # Original image
    ax1 = plt.subplot(1, 3, 1)
    img = denormalize(inputs[0], [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    img = img.permute(1, 2, 0).cpu().numpy()  # Move the tensor back to CPU for plotting
    ax1.imshow(img)
    ax1.set_title(f'True: {test_dataset.classes[labels[0].item()]}')  # Extract the scalar value from labels
    ax1.axis('off')

    # Heatmap
    ax2 = plt.subplot(1, 3, 2)
    ax2.imshow(heatmap, cmap='jet')  # Display the 2D heatmap
    ax2.set_title('Grad-CAM Heatmap')
    ax2.axis('off')

    # Overlay the heatmap on the image
    ax3 = plt.subplot(1, 3, 3)
    ax3.imshow(img)
    ax3.imshow(heatmap, cmap='jet', alpha=0.5)  # Overlay with transparency
    ax3.set_title(f'Predicted: {test_dataset.classes[predicted]}')
    ax3.axis('off')

    plt.tight_layout()
    plt.show()

    # Stop after the first example for demonstration; remove this line to iterate over all
    if i == 0:
        break
